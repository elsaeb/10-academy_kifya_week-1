# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import talib as ta

# %%
df = pd.read_csv("data/raw_analyst_ratings.csv")
df.shape
# Out:
# (1407328, 6)

# %%
df.head(10)
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
# 5           5  CFRA Maintains Hold on Agilent Technologies, L...
# 6           6  UBS Maintains Neutral on Agilent Technologies,...
# 7           7  Agilent Technologies shares are trading higher...
# 8           8  Wells Fargo Maintains Overweight on Agilent Te...
# 9           9         10 Biggest Price Target Changes For Friday
#
#                                                  url                publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...        Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...        Benzinga Insights
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407328 entries, 0 to 1407327
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1407328 non-null  int64
#  1   headline    1407328 non-null  object
#  2   url         1407328 non-null  object
#  3   publisher   1407328 non-null  object
#  4   date        1407328 non-null  object
#  5   stock       1407328 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 64.4+ MB

# %%
headlines = df['headline']

# %%
# Calculate the length of each headline by words
df['headline_length_words'] = headlines.apply(lambda x: len(x.split()))

# %%
print(df['headline_length_words'].head())
# Out:
# 0     7
# 1     7
# 2     5
# 3     7
# 4    14
# Name: headline_length_words, dtype: int64

# %%
# Calculate the length of each headline by characters
df['headline_length_characters'] = headlines.apply(len)

# Basic statistics for headline lengths (characters)
character_stats = df['headline_length_characters'].describe()

# Basic statistics for headline lengths (words)
word_stats = df['headline_length_words'].describe()

print("Character Length Statistics:\n", character_stats)
print("Word Length Statistics:\n", word_stats)
# Out:
# Character Length Statistics:
#  count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length_characters, dtype: float64
# Word Length Statistics:
#  count    1.407328e+06
# mean     1.141671e+01
# std      6.352997e+00
# min      1.000000e+00
# 25%      7.000000e+00
# 50%      1.000000e+01
# 75%      1.300000e+01
# max      7.700000e+01
# Name: headline_length_words, dtype: float64

# %%
# Count the number of articles per publisher
publisher_counts = df['publisher'].value_counts()

# Display the top 10 publishers by article count
print(publisher_counts.head(10))
print(df['publisher'].unique())
# Out:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64
# ['Benzinga Insights' 'Lisa Levin' 'Vick Meyer' ... 'Robert Morris'
#  'LeftCoastHedgie' 'Jeremie Capron']

# %%
# Convert the 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True, errors='coerce')
# Extract relevant components
df['weekdays'] = df['date'].dt.day_name()  # Extract day of the week
df['month'] = df['date'].dt.month_name()   # Extract month
df['year'] = df['date'].dt.year            # Extract year
df['date_only'] = df['date'].dt.date       # Extract only the date part (without time)
# Out:
# /tmp/ipykernel_3979/3782670222.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True, errors='coerce')

# %%
# Count the number of articles per day of the week
day_of_week_counts = df['weekdays'].value_counts()

# Count the number of articles per month
month_counts = df['month'].value_counts()

# Count the number of articles per year
year_counts = df['year'].value_counts()

# Count the number of articles per date (for specific day analysis)
date_counts = df['date_only'].value_counts().sort_index()

# %%
# Plot article frequency by day of the week
plt.figure(figsize=(10, 6))
day_of_week_counts.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']).plot(kind='bar')
plt.title('Article Frequency by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Articles')
plt.show()

# %%
# Plot article frequency by month
plt.figure(figsize=(10, 6))
month_counts.reindex(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']).plot(kind='bar')
plt.title('Article Frequency by Month')
plt.xlabel('Month')
plt.ylabel('Number of Articles')
plt.show()

# %%
# Plot article frequency by year
plt.figure(figsize=(10, 6))
year_counts.sort_index().plot(kind='bar')
plt.title('Article Frequency by Year')
plt.xlabel('Year')
plt.ylabel('Number of Articles')
plt.show()

# %%
# Plot article frequency over time (by specific date)
plt.figure(figsize=(12, 6))
date_counts.plot()
plt.title('Article Frequency Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.show()

# %%
from textblob import TextBlob

# Set the sample size (e.g., 10% of the dataset)
sample_size = 0.1  # 10% of the dataset

# Randomly select a sample of headlines
sample_df = df.sample(frac=sample_size, random_state=42)

# Perform sentiment analysis on the sampled data
from textblob import TextBlob

# Using TextBlob for sentiment analysis on the sampled data
sample_df['sentiment'] = sample_df['headline'].apply(lambda x: TextBlob(x).sentiment.polarity)

# Classify sentiment as positive, neutral, or negative
def classify_sentiment(score):
    if score > 0:
        return 'Positive'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Negative'

sample_df['sentiment_category'] = sample_df['sentiment'].apply(classify_sentiment)

# Display the distribution of sentiments in the sample
sentiment_counts_sample = sample_df['sentiment_category'].value_counts()
print(sentiment_counts_sample)
# Out:
# sentiment_category
# Neutral     93582
# Positive    34000
# Negative    13151
# Name: count, dtype: int64

# %%
import random
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Set the percentage of data to sample
sample_fraction = 0.1

# Select a random sample of 10% of the data
random_sample = df.sample(frac=sample_fraction, random_state=42)

# Extract the 'headline' column
headlines = random_sample['headline'].tolist()

# Preview the first few random headlines
print(headlines[:5])
# Out:
# ['Syntel, Inc. Reports Q1 EPS of $1.11 vs $1.03 Est; Revenue of $189.10M vs $187.99M Est', 'Mid-Day Market Update: K2M Group Rises On Acquisition News; Tech Data Shares Plunge', "Aramchol's Failed Past Isn't Its Future; Galmed Gets An Upgrade", "60 Stocks Moving In Thursday's Mid-Day Session", 'Anheuser-Busch shares are trading lower after the company said it is not proceeding with its public offering of its minority stake in APAC subsidiary.']

# %%
# Initialize the VADER sentiment intensity analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to get VADER sentiment
def vader_sentiment(text):
    # Get the sentiment scores
    sentiment_dict = analyzer.polarity_scores(text)
    # Classify sentiment
    if sentiment_dict['compound'] >= 0.05:
        return 'Positive'
    elif sentiment_dict['compound'] <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Analyze sentiments of the random headlines
random_sample['Sentiment'] = random_sample['headline'].apply(vader_sentiment)

# Display the first 10 results
print(random_sample[['headline', 'Sentiment']].head(10))
# Out:
#                                                   headline Sentiment
# 1201723  Syntel, Inc. Reports Q1 EPS of $1.11 vs $1.03 ...   Neutral
# 1282616  Mid-Day Market Update: K2M Group Rises On Acqu...  Positive
# 554075   Aramchol's Failed Past Isn't Its Future; Galme...  Negative
# 1190332     60 Stocks Moving In Thursday's Mid-Day Session   Neutral
# 192958   Anheuser-Busch shares are trading lower after ...   Neutral
# 996906          The Market In 5 Minutes: Don't Stop Me Now  Positive
# 606689   Hawaiian Electric Industries, Inc. Reports Q3 ...   Neutral
# 821630   Valuation Flies Higher On Macquarie Infrastruc...   Neutral
# 362771   DISH Network Reports Q2 EPS $0.75 vs $0.79 Est...   Neutral
# 258731   21st Century Fox Rejected Higher Offer From Co...  Negative

# %%
# Count the occurrences of each sentiment
sentiment_counts = random_sample['Sentiment'].value_counts()

# Print the sentiment distribution
print(sentiment_counts)

# Plot sentiment distribution
import matplotlib.pyplot as plt

# Plot the sentiment distribution as a bar chart
sentiment_counts.plot(kind='bar', color=['gray','green','red'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Number of Headlines')
plt.show()
# Out:
# Sentiment
# Neutral     73635
# Positive    44424
# Negative    22674
# Name: count, dtype: int64

# %%
print(sentiment_counts)
# Out:
# Sentiment
# Neutral     73635
# Positive    44424
# Negative    22674
# Name: count, dtype: int64

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import corpora

# Download necessary NLTK data files
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Initialize NLTK tools
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Function to preprocess headlines
def preprocess_text(text):
    tokens = word_tokenize(text.lower())  # Tokenize and convert to lowercase
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalpha()]  # Lemmatize and remove non-alphabetic tokens
    tokens = [token for token in tokens if token not in stop_words]  # Remove stopwords
    return tokens
sample_size = 0.1
sample_df['sentiment'] = sample_df['headline'].apply(preprocess_text)

# Create a dictionary and a corpus
dictionary = corpora.Dictionary(processed_headlines)
corpus = [dictionary.doc2bow(text) for text in processed_headlines]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/gensim/matutils.py:1356
#    1355 try:
# -> 1356     from gensim.corpora._mmreader import MmReader  # noqa: F401
#    1357 except ImportError:
#
# File ~/.local/lib/python3.10/site-packages/gensim/corpora/_mmreader.pyx:11, in init gensim.corpora._mmreader()
#
# ImportError: cannot import name utils
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[66], line 5
#       3 from nltk.tokenize import word_tokenize
#       4 from nltk.stem import WordNetLemmatizer
# ----> 5 import gensim
#       6 from gensim import corpora
#       8 # Download necessary NLTK data files
#
# File ~/.local/lib/python3.10/site-packages/gensim/__init__.py:11
#       7 __version__ = '4.3.3'
# ...

# %%
# Count contributions by publisher
publisher_counts = df['publisher'].value_counts()
print(publisher_counts)
# Out:
# publisher
# Paul Quintaro                      228373
# Lisa Levin                         186979
# Benzinga Newsdesk                  150484
# Charles Gross                       96732
# Monica Gerson                       82380
#                                     ...
# Shazir Mucklai - Imperium Group         1
# Laura Jennings                          1
# Eric Martin                             1
# Jose Rodrigo                            1
# Jeremie Capron                          1
# Name: count, Length: 1034, dtype: int64

# %%
# Extract domains from email addresses
df['domain'] = df['publisher'].apply(lambda x: x.split('@')[-1] if '@' in x else None)

# Count contributions by domain
domain_counts = df['domain'].value_counts()
print(domain_counts)
# Out:
# domain
# benzinga.com              7937
# gmail.com                  139
# andyswan.com                 5
# investdiva.com               2
# tothetick.com                2
# eosdetroit.io                1
# forextraininggroup.com       1
# stockmetrix.net              1
# Name: count, dtype: int64

# %% [raw]
# df['domain'] = df['publisher'].apply(lambda x: x.split('@')[-1] if '@' in x else None)
#
# domain_counts = df['domain'].value_counts()
# print(domain_counts)
